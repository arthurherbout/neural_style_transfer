# %%
import tensorflow as tf

# %%
import tensorflow_hub as hub

# %%
from matplotlib import pyplot as plt

# %%
content_image = plt.imread("../data/horses.jpeg")

# %%
style_image = plt.imread("../data/Van_Gogh-Starry_Night.jpeg")

# %%
plt.imshow(content_image)
plt.show()

# %%
content_image.shape
# Out:
# (3024, 4032, 3)

# %%
plt.imshow(style_image)
plt.show()

# %%
style_image.shape
# Out:
# (1622, 2048, 3)

# %% [markdown]
# # preprocess

# %%
import numpy as np

# %%
content_image = content_image.astype(np.float32)[np.newaxis, ...] / 255.
style_image = style_image.astype(np.float32)[np.newaxis, ...] / 255.

# %%
style_image = tf.image.resize(style_image, (256, 256))

# %%
content_image = tf.image.resize(content_image, (512, 512))

# %% [markdown]
# # Load Image stylization module

# %%
# Load image stylization module.
hub_module = hub.load('https://tfhub.dev/google/magenta/arbitrary-image-stylization-v1-256/2')

# %%
# Stylize image.
outputs = hub_module(tf.constant(content_image), tf.constant(style_image))

# %%
stylized_image = outputs[0]

# %%
plt.imshow(stylized_image.numpy()[0])
plt.imsave(arr=stylized_image.numpy()[0],"../data/test_1.jpeg")
plt.show()
# Out:
#   File "<ipython-input-31-f8b6c145b7e8>", line 2
#     plt.imsave(arr=stylized_image.numpy()[0],"../data/test_1.jpeg")
#                                              ^
# SyntaxError: positional argument follows keyword argument

# %%
plt.imsave(styl)
